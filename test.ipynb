# %%
import pandas as pd

# Read the CSV file with specific columns and data types
df_raw = pd.read_csv(
    r"datasets/ASWSIndexEOD.csv",
    skiprows=[1],  # Skip the second row
    usecols=["S_INFO_WINDCODE", "TRADE_DT", "S_DQ_CLOSE"],  # Only read key fields
    parse_dates=["TRADE_DT"],  # Parse date column
    dtype={"S_DQ_CLOSE": "float64"}  # Ensure close price is float type
)

# Display basic information about the dataset
print("Dataset shape:", df_raw.shape)
print("\nFirst 5 rows:")
print(df_raw.head())
print("\nData types:")
print(df_raw.dtypes)
# Out:
# Dataset shape: (3690077, 3)
#
# First 5 rows:
#   S_INFO_WINDCODE   TRADE_DT  S_DQ_CLOSE
# 0       801001.SI 2000-01-04     1042.67
# 1       801001.SI 2000-01-05     1041.59
# 2       801001.SI 2000-01-06     1094.61
# 3       801001.SI 2000-01-07     1141.75
# 4       801001.SI 2000-01-10     1162.06
#
# Data types:
# S_INFO_WINDCODE            object
# TRADE_DT           datetime64[ns]
# S_DQ_CLOSE                float64
# dtype: object
